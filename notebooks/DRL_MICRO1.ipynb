# %% [markdown]
# # Configuracion de ambiente

# %%
#Descarga librerías no incluidas en Colab usando pip
# !pip install stable_baselines3 #Stable Baselines3 -> Framework de Reinforcement Learning
# !pip install sb3-contrib #SB3-Contrib es un repositorio aparte con otros algoritmos
# !pip install ale-py #ALE se utiliza para el ambiente de Atari
# !pip install "gymnasium[atari,accept-rom-license]" stable-baselines3 autorom renderlab -q #Gymnasium, envs de Atari y ROM
# !pip install swig
# !pip install "gymnasium[box2d]" # Corrected: Added closing double quote
# !AutoROM --accept-license
# !pip install renderlab #usado para renderizar gym

import stable_baselines3 #importa Stable Baselines3
from stable_baselines3 import DQN #importa el agente/algoritmo de DQN
from stable_baselines3.common.logger import configure #importa herramientas de logger/debug
from stable_baselines3.common.logger import Logger, CSVOutputFormat, HumanOutputFormat #importa herramientas de logger/debug
from stable_baselines3.common.evaluation import evaluate_policy #importa herramienta de evaluación automática
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv
from sb3_contrib import QRDQN #importa el agente/algoritmo de QRDQN
import gymnasium as gymnasium #importa la libreria de gymnasium con las simulaciones
import renderlab #importa renderlab para los videos
from gymnasium.spaces import Box # Added for PixelObservationWrapper

import ale_py #importa ale para los ambientes de Atari
from gymnasium.wrappers import TimeLimit #importa timelimit para acortar los episodios
from stable_baselines3.common.env_util import make_atari_env #importa make_atari_env para escala de grises
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack #importa VecFrameStack para apilar frames y acelerar así el entrenamiento
from collections import deque #importa para ajustar los videos con VecFrameStack
import cv2 #importa para ajustar los videos con VecFrameStack

#!Importante:
gymnasium.register_envs(ale_py) #Hay que registrar los entornos de ALE manualmente!!!

#Importa otras librerías básicas
import numpy as np
import matplotlib.pyplot as plt
import random
import math
import pandas as pd
import sys
import os

#Limpia los registros generados
from IPython.display import clear_output
clear_output()
print("Todas las librerías han sido instaladas correctamente.")
# Out:
# Todas las librerías han sido instaladas correctamente.

# %%
import subprocess

subprocess.run(["AutoROM"], input="Y\n", text=True)
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# CompletedProcess(args=['AutoROM'], returncode=0)

# %%
def load_weights_into_new_model(model_class, policy, env, load_path, **kwargs):
    """
    Crea un modelo NUEVO con hiperparámetros kwargs,
    carga el modelo VIEJO desde load_path,
    y copia los pesos del viejo al nuevo.
    Retorna el modelo nuevo listo para entrenar.
    """
    new_model = model_class(policy, env, **kwargs)
    old_model = model_class.load(load_path, env=env)
    new_model.set_parameters(old_model.get_parameters())
    return new_model

# %%
# =========================
# Callback para registrar recompensa por episodio
# =========================
class RewardLoggerCallback(BaseCallback):
    def __init__(self):
        super().__init__()
        self.episode_rewards = []

    def _on_step(self) -> bool:
        if len(self.locals.get("infos", [])) > 0:
            for info in self.locals["infos"]:
                if "episode" in info:
                    self.episode_rewards.append(info["episode"]["r"])
        return True

# %%
# =========================
# Env wrapper: parámetros FIJOS (apto para DQN/DDQN)
# (NO recrea el env en cada reset)
# =========================
class FixedLunarLander(gymnasium.Env):
    metadata = {"render_modes": ["rgb_array", None]}

    def __init__(
        self,
        continuous=False,
        gravity=-10.0,
        enable_wind=False,
        wind_power=0.0,
        turbulence_power=0.0,
        render_mode=None,
        seed=None
    ):
        super().__init__()
        self.continuous = continuous
        self.gravity = float(gravity)
        self.enable_wind = bool(enable_wind)
        self.wind_power = float(wind_power)
        self.turbulence_power = float(turbulence_power)
        self.render_mode = render_mode
        self._seed = seed

        self.env = gymnasium.make(
            "LunarLander-v3",
            continuous=self.continuous,
            gravity=self.gravity,
            enable_wind=self.enable_wind,
            wind_power=self.wind_power,
            turbulence_power=self.turbulence_power,
            render_mode=self.render_mode
        )

        # expone spaces
        self.action_space = self.env.action_space
        self.observation_space = self.env.observation_space

        if self._seed is not None:
            self.env.reset(seed=self._seed)

    def reset(self, *, seed=None, options=None):
        # OJO: no se recrea el env, solo se resetea
        if seed is not None:
            self._seed = seed
        return self.env.reset(seed=self._seed, options=options)

    def step(self, action):
        return self.env.step(action)

    def render(self):
        return self.env.render()

    def close(self):
        if self.env is not None:
            self.env.close()

# %%
# =========================
# Trainer integrado (DQN / "DDQN en SB3")
# =========================
class LunarLanderTrainer:
    def __init__(
        self,
        model_fn,
        continuous=False,
        gravity=-10.0,
        enable_wind=False,
        wind_power=0.0,
        turbulence_power=0.0,
        total_timesteps=500_000,
        log_dir="./logs",
        n_envs=8
    ):
        self.continuous = continuous
        self.gravity = gravity # Store as instance attribute
        self.enable_wind = enable_wind # Store as instance attribute
        self.wind_power = wind_power # Store as instance attribute
        self.turbulence_power = turbulence_power # Store as instance attribute
        self.total_timesteps = total_timesteps
        self.log_dir = log_dir
        os.makedirs(log_dir, exist_ok=True)

        def make_env(i):
            def _init():
                env = gymnasium.make(
                    "LunarLander-v3",
                    continuous=False,
                    gravity=self.gravity,
                    enable_wind=self.enable_wind,
                    wind_power=self.wind_power,
                    turbulence_power=self.turbulence_power,
                    render_mode=None
                )
                # Shorter horizon helps avoid "hover forever" policies
                env = TimeLimit(env, max_episode_steps=600)

                env = Monitor(env)
                env.reset(seed=1000 + i)
                return env
            return _init

        self.env = DummyVecEnv([make_env(i) for i in range(n_envs)])

        self.model = model_fn(self.env)

        new_logger = configure(log_dir, ["stdout", "csv"])
        self.model.set_logger(new_logger)

        self.callback = RewardLoggerCallback()

    def train(self, save_path="dqn_lunarlander_model"):
        self.model.learn(
            total_timesteps=self.total_timesteps,
            log_interval=20,
            callback=self.callback
        )
        self.model.save(save_path)
        print(f"Training complete. Model saved at: {save_path}")

    def plot_rewards(self):
        if not self.callback.episode_rewards:
            print("No reward data to plot.")
            return
        plt.figure(figsize=(10, 5))
        plt.plot(self.callback.episode_rewards, label="Episode Reward")
        plt.xlabel("Episodes")
        plt.ylabel("Reward")
        plt.title("Training Rewards Over Time")
        plt.grid()
        plt.legend()
        plt.tight_layout()
        plt.show()

    def evaluate(self, n_eval_episodes=100):
        import numpy as np
        from stable_baselines3.common.vec_env import DummyVecEnv
        from stable_baselines3.common.monitor import Monitor
        from stable_baselines3.common.evaluation import evaluate_policy

        def make_eval_env():
            env = FixedLunarLander(
                continuous=self.continuous,
                gravity=self.gravity,
                enable_wind=self.enable_wind,
                wind_power=self.wind_power,
                turbulence_power=self.turbulence_power,
                render_mode=None,
                seed=None  # no fijar seed aquí
            )
            return Monitor(env)

        eval_env = DummyVecEnv([make_eval_env])

        rewards = []
        for ep in range(n_eval_episodes):
            # cambia seed cada episodio para que el terreno cambie
            eval_env.env_method("reset", seed=10_000 + ep)
            r, _ = evaluate_policy(self.model, eval_env, n_eval_episodes=1, deterministic=True)
            rewards.append(float(r))

        mean_reward = float(np.mean(rewards))
        std_reward = float(np.std(rewards))

        print(f"Eval mean reward over {n_eval_episodes} episodes: {mean_reward:.2f} +/- {std_reward:.2f}")
        print("✅ SOLVED (>=200)" if mean_reward >= 200 else "❌ Not solved yet")
        return mean_reward, std_reward


    def generate_video(self, model_path="dqn_lunarlander_model", out_dir="./output_video"):
        os.makedirs(out_dir, exist_ok=True)

        model = self.model.__class__.load(model_path)

        # Env para video con render
        # Using trainer's own initialized parameters for consistency
        env = FixedLunarLander(
            continuous=self.continuous,
            gravity=self.gravity,
            enable_wind=self.enable_wind,
            wind_power=self.wind_power,
            turbulence_power=self.turbulence_power,
            render_mode="rgb_array",
            seed=123
        )
        env = renderlab.RenderFrame(env, out_dir)

        obs, info = env.reset()
        terminated, truncated = False, False
        total_reward = 0.0

        while not (terminated or truncated):
            action, _ = model.predict(obs, deterministic=True)
            obs, reward, terminated, truncated, info = env.step(action)
            total_reward += reward

        print("Recompensa obtenida en el episodio (video):", total_reward)
        env.play()
        env.close()

# %% [markdown]
# # Stage 1 strong

# %%
# =========================
# Model factory (DQN / "DDQN en SB3")
# =========================
def create_dqn_model_stage1_strong(env):
    return DQN(
        "MlpPolicy",
        env,
        learning_rate=1e-3,
        buffer_size=200_000,
        learning_starts=10_000,
        batch_size=64,
        gamma=0.99,
        train_freq=4,
        gradient_steps=1,
        target_update_interval=1_000,
        exploration_fraction=0.2,
        exploration_initial_eps=1.0,
        exploration_final_eps=0.05,
        policy_kwargs=dict(net_arch=[256, 256]),
        verbose=1
    )

# %%
# from stable_baselines3 import DQN

# def run_stage(
#     stage_name: str,
#     timesteps: int,
#     gravity: float,
#     enable_wind: bool,
#     wind_power: float,
#     turbulence_power: float,
#     model_fn,
#     load_model_path: str | None,
#     save_model_path: str,
#     n_envs: int = 8,
# ):
#     # crea trainer con parámetros del escenario
#     trainer = LunarLanderTrainer(
#         model_fn=model_fn,
#         continuous=False,
#         gravity=gravity,
#         enable_wind=enable_wind,
#         wind_power=wind_power,
#         turbulence_power=turbulence_power,
#         total_timesteps=timesteps,
#         log_dir=f"./logs_{stage_name}",
#         n_envs=n_envs
#     )

#     # si hay modelo previo, lo cargamos y seguimos entrenando en el nuevo env
#     if load_model_path is not None:
#         trainer.model = DQN.load(load_model_path, env=trainer.env)
#         print(f"[{stage_name}] Loaded model: {load_model_path}")

#     # entrena, guarda y evalúa
#     trainer.train(save_path=save_model_path)
#     trainer.evaluate(
#         n_eval_episodes=100
#         # Removed gravity, enable_wind, wind_power, turbulence_power as evaluate method uses trainer's own attributes
#     )
#     return trainer

# %%
trainer1 = LunarLanderTrainer(
    model_fn=create_dqn_model_stage1_strong,
    gravity=-10.0,
    enable_wind=False,
    wind_power=0.0,
    turbulence_power=0.0,
    total_timesteps=1_200_000,
    log_dir="./logs_stage1_sanity",
    n_envs=1
)
trainer1.train("lander_stage1_sanity")
trainer1.evaluate(100)
# Out:
# WARNING:py.warnings:<frozen importlib._bootstrap>:488: DeprecationWarning: builtin type SwigPyPacked has no __module__ attribute
#
# WARNING:py.warnings:<frozen importlib._bootstrap>:488: DeprecationWarning: builtin type SwigPyObject has no __module__ attribute
#
# WARNING:py.warnings:<frozen importlib._bootstrap>:488: DeprecationWarning: builtin type swigvarlink has no __module__ attribute
# Using cuda device
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Logging to ./logs_stage1_sanity
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.8     |
# |    ep_rew_mean      | -224     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 5213     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1736     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.7     |
# |    ep_rew_mean      | -211     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 5994     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3667     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -211     |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 6180     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5409     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -205     |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 6402     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7388     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.9     |
# |    ep_rew_mean      | -201     |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 6492     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9186     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.2     |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 2480     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 10956    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.69     |
# |    n_updates        | 238      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.949    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1647     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 12820    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.523    |
# |    n_updates        | 704      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93       |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.942    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 1401     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 14707    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.38     |
# |    n_updates        | 1176     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | -155     |
# |    exploration_rate | 0.934    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1378     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 16586    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.09     |
# |    n_updates        | 1646     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.7     |
# |    ep_rew_mean      | -148     |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1354     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 18552    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.28     |
# |    n_updates        | 2137     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.4     |
# |    ep_rew_mean      | -147     |
# |    exploration_rate | 0.919    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1298     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 20393    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 5.23     |
# |    n_updates        | 2598     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.7     |
# |    ep_rew_mean      | -140     |
# |    exploration_rate | 0.912    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1289     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 22192    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.12     |
# |    n_updates        | 3047     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.5     |
# |    ep_rew_mean      | -130     |
# |    exploration_rate | 0.905    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1280     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 24058    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.96     |
# |    n_updates        | 3514     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.4     |
# |    ep_rew_mean      | -131     |
# |    exploration_rate | 0.897    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 1275     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 25922    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.85     |
# |    n_updates        | 3980     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -118     |
# |    exploration_rate | 0.89     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 1268     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 27679    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.327    |
# |    n_updates        | 4419     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -104     |
# |    exploration_rate | 0.884    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 1263     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 29414    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 6.28     |
# |    n_updates        | 4853     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | -101     |
# |    exploration_rate | 0.876    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 1258     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 31296    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.56     |
# |    n_updates        | 5323     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -102     |
# |    exploration_rate | 0.868    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 1240     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 33267    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.46     |
# |    n_updates        | 5816     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.2     |
# |    ep_rew_mean      | -99.7    |
# |    exploration_rate | 0.861    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 1226     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 35138    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.433    |
# |    n_updates        | 6284     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.9     |
# |    ep_rew_mean      | -107     |
# |    exploration_rate | 0.853    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 1221     |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 37072    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.31     |
# |    n_updates        | 6767     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.3     |
# |    ep_rew_mean      | -109     |
# |    exploration_rate | 0.846    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 1219     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 38942    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.524    |
# |    n_updates        | 7235     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.6     |
# |    ep_rew_mean      | -110     |
# |    exploration_rate | 0.839    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 1214     |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 40653    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 13.7     |
# |    n_updates        | 7663     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | -107     |
# |    exploration_rate | 0.832    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 1211     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 42464    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.307    |
# |    n_updates        | 8115     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.6     |
# |    ep_rew_mean      | -107     |
# |    exploration_rate | 0.825    |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 1208     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 44301    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.52     |
# |    n_updates        | 8575     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97       |
# |    ep_rew_mean      | -102     |
# |    exploration_rate | 0.815    |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 1193     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 46775    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.451    |
# |    n_updates        | 9193     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.3     |
# |    ep_rew_mean      | -97.6    |
# |    exploration_rate | 0.807    |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 1186     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 48676    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.507    |
# |    n_updates        | 9668     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99       |
# |    ep_rew_mean      | -93.2    |
# |    exploration_rate | 0.8      |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 1184     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 50550    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.97     |
# |    n_updates        | 10137    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -90.3    |
# |    exploration_rate | 0.792    |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 1182     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 52474    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.16     |
# |    n_updates        | 10618    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.8     |
# |    ep_rew_mean      | -82.8    |
# |    exploration_rate | 0.785    |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 1178     |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 54285    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 5.29     |
# |    n_updates        | 11071    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.6     |
# |    ep_rew_mean      | -83.9    |
# |    exploration_rate | 0.778    |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 1176     |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 56035    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.997    |
# |    n_updates        | 11508    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -85.9    |
# |    exploration_rate | 0.77     |
# | time/               |          |
# |    episodes         | 620      |
# |    fps              | 1173     |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 58000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.575    |
# |    n_updates        | 11999    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.9     |
# |    ep_rew_mean      | -85.1    |
# |    exploration_rate | 0.763    |
# | time/               |          |
# |    episodes         | 640      |
# |    fps              | 1161     |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 59839    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.29     |
# |    n_updates        | 12459    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | -84.9    |
# |    exploration_rate | 0.756    |
# | time/               |          |
# |    episodes         | 660      |
# |    fps              | 1156     |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 61669    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.87     |
# |    n_updates        | 12917    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.6     |
# |    ep_rew_mean      | -86.6    |
# |    exploration_rate | 0.748    |
# | time/               |          |
# |    episodes         | 680      |
# |    fps              | 1154     |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 63541    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.76     |
# |    n_updates        | 13385    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.9     |
# |    ep_rew_mean      | -83.8    |
# |    exploration_rate | 0.741    |
# | time/               |          |
# |    episodes         | 700      |
# |    fps              | 1152     |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 65522    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.32     |
# |    n_updates        | 13880    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.6     |
# |    ep_rew_mean      | -80.9    |
# |    exploration_rate | 0.734    |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 1149     |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 67264    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 8.94     |
# |    n_updates        | 14315    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.1     |
# |    ep_rew_mean      | -81.3    |
# |    exploration_rate | 0.726    |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 1146     |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 69150    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 5.8      |
# |    n_updates        | 14787    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.8     |
# |    ep_rew_mean      | -82      |
# |    exploration_rate | 0.72     |
# | time/               |          |
# |    episodes         | 760      |
# |    fps              | 1143     |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 70848    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.57     |
# |    n_updates        | 15211    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.9     |
# |    ep_rew_mean      | -78.9    |
# |    exploration_rate | 0.712    |
# | time/               |          |
# |    episodes         | 780      |
# |    fps              | 1134     |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 72730    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1        |
# |    n_updates        | 15682    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -77.1    |
# |    exploration_rate | 0.705    |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 1132     |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 74545    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.89     |
# |    n_updates        | 16136    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.2     |
# |    ep_rew_mean      | -79      |
# |    exploration_rate | 0.697    |
# | time/               |          |
# |    episodes         | 820      |
# |    fps              | 1131     |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 76486    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.703    |
# |    n_updates        | 16621    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -77.9    |
# |    exploration_rate | 0.69     |
# | time/               |          |
# |    episodes         | 840      |
# |    fps              | 1129     |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 78270    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.06     |
# |    n_updates        | 17067    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -73.4    |
# |    exploration_rate | 0.683    |
# | time/               |          |
# |    episodes         | 860      |
# |    fps              | 1127     |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 80074    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.825    |
# |    n_updates        | 17518    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.9     |
# |    ep_rew_mean      | -74.2    |
# |    exploration_rate | 0.676    |
# | time/               |          |
# |    episodes         | 880      |
# |    fps              | 1125     |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 81821    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.806    |
# |    n_updates        | 17955    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93       |
# |    ep_rew_mean      | -76.1    |
# |    exploration_rate | 0.668    |
# | time/               |          |
# |    episodes         | 900      |
# |    fps              | 1119     |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 83840    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.14     |
# |    n_updates        | 18459    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -73.8    |
# |    exploration_rate | 0.661    |
# | time/               |          |
# |    episodes         | 920      |
# |    fps              | 1101     |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 85612    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.21     |
# |    n_updates        | 18902    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.5     |
# |    ep_rew_mean      | -73.2    |
# |    exploration_rate | 0.653    |
# | time/               |          |
# |    episodes         | 940      |
# |    fps              | 1099     |
# |    time_elapsed     | 79       |
# |    total_timesteps  | 87716    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.881    |
# |    n_updates        | 19428    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.5     |
# |    ep_rew_mean      | -74.2    |
# |    exploration_rate | 0.645    |
# | time/               |          |
# |    episodes         | 960      |
# |    fps              | 1098     |
# |    time_elapsed     | 81       |
# |    total_timesteps  | 89720    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.685    |
# |    n_updates        | 19929    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.1     |
# |    ep_rew_mean      | -74.3    |
# |    exploration_rate | 0.638    |
# | time/               |          |
# |    episodes         | 980      |
# |    fps              | 1097     |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 91528    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.02     |
# |    n_updates        | 20381    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.4     |
# |    ep_rew_mean      | -69      |
# |    exploration_rate | 0.629    |
# | time/               |          |
# |    episodes         | 1000     |
# |    fps              | 1094     |
# |    time_elapsed     | 85       |
# |    total_timesteps  | 93680    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.731    |
# |    n_updates        | 20919    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -65.5    |
# |    exploration_rate | 0.621    |
# | time/               |          |
# |    episodes         | 1020     |
# |    fps              | 1087     |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 95748    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.16     |
# |    n_updates        | 21436    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -61.2    |
# |    exploration_rate | 0.613    |
# | time/               |          |
# |    episodes         | 1040     |
# |    fps              | 1085     |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 97743    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.537    |
# |    n_updates        | 21935    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | -60.4    |
# |    exploration_rate | 0.603    |
# | time/               |          |
# |    episodes         | 1060     |
# |    fps              | 1083     |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 100211   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.799    |
# |    n_updates        | 22552    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | -54.2    |
# |    exploration_rate | 0.596    |
# | time/               |          |
# |    episodes         | 1080     |
# |    fps              | 1082     |
# |    time_elapsed     | 94       |
# |    total_timesteps  | 102166   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.728    |
# |    n_updates        | 23041    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | -51.8    |
# |    exploration_rate | 0.587    |
# | time/               |          |
# |    episodes         | 1100     |
# |    fps              | 1080     |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 104219   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.3      |
# |    n_updates        | 23554    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 112      |
# |    ep_rew_mean      | -45.7    |
# |    exploration_rate | 0.577    |
# | time/               |          |
# |    episodes         | 1120     |
# |    fps              | 1074     |
# |    time_elapsed     | 99       |
# |    total_timesteps  | 106925   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.871    |
# |    n_updates        | 24231    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -39.7    |
# |    exploration_rate | 0.568    |
# | time/               |          |
# |    episodes         | 1140     |
# |    fps              | 1072     |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 109011   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.16     |
# |    n_updates        | 24752    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 115      |
# |    ep_rew_mean      | -35.6    |
# |    exploration_rate | 0.558    |
# | time/               |          |
# |    episodes         | 1160     |
# |    fps              | 1070     |
# |    time_elapsed     | 104      |
# |    total_timesteps  | 111691   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.51     |
# |    n_updates        | 25422    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 116      |
# |    ep_rew_mean      | -39.2    |
# |    exploration_rate | 0.55     |
# | time/               |          |
# |    episodes         | 1180     |
# |    fps              | 1069     |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 113793   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.06     |
# |    n_updates        | 25948    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 116      |
# |    ep_rew_mean      | -37.9    |
# |    exploration_rate | 0.541    |
# | time/               |          |
# |    episodes         | 1200     |
# |    fps              | 1067     |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 115869   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.52     |
# |    n_updates        | 26467    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 121      |
# |    ep_rew_mean      | -42.6    |
# |    exploration_rate | 0.529    |
# | time/               |          |
# |    episodes         | 1220     |
# |    fps              | 1061     |
# |    time_elapsed     | 112      |
# |    total_timesteps  | 119029   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.05     |
# |    n_updates        | 27257    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 125      |
# |    ep_rew_mean      | -44.6    |
# |    exploration_rate | 0.519    |
# | time/               |          |
# |    episodes         | 1240     |
# |    fps              | 1059     |
# |    time_elapsed     | 114      |
# |    total_timesteps  | 121532   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.41     |
# |    n_updates        | 27882    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 122      |
# |    ep_rew_mean      | -41      |
# |    exploration_rate | 0.51     |
# | time/               |          |
# |    episodes         | 1260     |
# |    fps              | 1057     |
# |    time_elapsed     | 117      |
# |    total_timesteps  | 123864   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.634    |
# |    n_updates        | 28465    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 125      |
# |    ep_rew_mean      | -35.1    |
# |    exploration_rate | 0.5      |
# | time/               |          |
# |    episodes         | 1280     |
# |    fps              | 1055     |
# |    time_elapsed     | 119      |
# |    total_timesteps  | 126251   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.61     |
# |    n_updates        | 29062    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 123      |
# |    ep_rew_mean      | -31.9    |
# |    exploration_rate | 0.493    |
# | time/               |          |
# |    episodes         | 1300     |
# |    fps              | 1054     |
# |    time_elapsed     | 121      |
# |    total_timesteps  | 128162   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.24     |
# |    n_updates        | 29540    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 115      |
# |    ep_rew_mean      | -25.3    |
# |    exploration_rate | 0.483    |
# | time/               |          |
# |    episodes         | 1320     |
# |    fps              | 1048     |
# |    time_elapsed     | 124      |
# |    total_timesteps  | 130566   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 7.77     |
# |    n_updates        | 30141    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 122      |
# |    ep_rew_mean      | -22.1    |
# |    exploration_rate | 0.471    |
# | time/               |          |
# |    episodes         | 1340     |
# |    fps              | 1046     |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 133759   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.17     |
# |    n_updates        | 30939    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 141      |
# |    ep_rew_mean      | -17.2    |
# |    exploration_rate | 0.454    |
# | time/               |          |
# |    episodes         | 1360     |
# |    fps              | 1042     |
# |    time_elapsed     | 132      |
# |    total_timesteps  | 137942   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.623    |
# |    n_updates        | 31985    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 158      |
# |    ep_rew_mean      | -10.1    |
# |    exploration_rate | 0.438    |
# | time/               |          |
# |    episodes         | 1380     |
# |    fps              | 1035     |
# |    time_elapsed     | 137      |
# |    total_timesteps  | 142096   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.86     |
# |    n_updates        | 33023    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | -5.17    |
# |    exploration_rate | 0.415    |
# | time/               |          |
# |    episodes         | 1400     |
# |    fps              | 1031     |
# |    time_elapsed     | 143      |
# |    total_timesteps  | 147849   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.39     |
# |    n_updates        | 34462    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 223      |
# |    ep_rew_mean      | -4.06    |
# |    exploration_rate | 0.395    |
# | time/               |          |
# |    episodes         | 1420     |
# |    fps              | 1024     |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 152853   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.26     |
# |    n_updates        | 35713    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 231      |
# |    ep_rew_mean      | -1.34    |
# |    exploration_rate | 0.379    |
# | time/               |          |
# |    episodes         | 1440     |
# |    fps              | 1021     |
# |    time_elapsed     | 153      |
# |    total_timesteps  | 156838   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.09     |
# |    n_updates        | 36709    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 270      |
# |    ep_rew_mean      | 9.34     |
# |    exploration_rate | 0.347    |
# | time/               |          |
# |    episodes         | 1460     |
# |    fps              | 1013     |
# |    time_elapsed     | 162      |
# |    total_timesteps  | 164925   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.33     |
# |    n_updates        | 38731    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 304      |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.317    |
# | time/               |          |
# |    episodes         | 1480     |
# |    fps              | 1005     |
# |    time_elapsed     | 171      |
# |    total_timesteps  | 172456   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.37     |
# |    n_updates        | 40613    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 331      |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.284    |
# | time/               |          |
# |    episodes         | 1500     |
# |    fps              | 998      |
# |    time_elapsed     | 181      |
# |    total_timesteps  | 180921   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.27     |
# |    n_updates        | 42730    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 366      |
# |    ep_rew_mean      | 33.9     |
# |    exploration_rate | 0.25     |
# | time/               |          |
# |    episodes         | 1520     |
# |    fps              | 989      |
# |    time_elapsed     | 191      |
# |    total_timesteps  | 189501   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.04     |
# |    n_updates        | 44875    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 422      |
# |    ep_rew_mean      | 46.5     |
# |    exploration_rate | 0.212    |
# | time/               |          |
# |    episodes         | 1540     |
# |    fps              | 980      |
# |    time_elapsed     | 203      |
# |    total_timesteps  | 199080   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.71     |
# |    n_updates        | 47269    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 456      |
# |    ep_rew_mean      | 47.5     |
# |    exploration_rate | 0.167    |
# | time/               |          |
# |    episodes         | 1560     |
# |    fps              | 970      |
# |    time_elapsed     | 216      |
# |    total_timesteps  | 210496   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.12     |
# |    n_updates        | 50123    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 496      |
# |    ep_rew_mean      | 53.2     |
# |    exploration_rate | 0.121    |
# | time/               |          |
# |    episodes         | 1580     |
# |    fps              | 958      |
# |    time_elapsed     | 231      |
# |    total_timesteps  | 222044   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.38     |
# |    n_updates        | 53010    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 526      |
# |    ep_rew_mean      | 56.4     |
# |    exploration_rate | 0.0756   |
# | time/               |          |
# |    episodes         | 1600     |
# |    fps              | 947      |
# |    time_elapsed     | 246      |
# |    total_timesteps  | 233525   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.45     |
# |    n_updates        | 55881    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 558      |
# |    ep_rew_mean      | 63.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1620     |
# |    fps              | 938      |
# |    time_elapsed     | 261      |
# |    total_timesteps  | 245342   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.04     |
# |    n_updates        | 58835    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 566      |
# |    ep_rew_mean      | 79.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1640     |
# |    fps              | 930      |
# |    time_elapsed     | 274      |
# |    total_timesteps  | 255701   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.29     |
# |    n_updates        | 61425    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 548      |
# |    ep_rew_mean      | 104      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1660     |
# |    fps              | 924      |
# |    time_elapsed     | 287      |
# |    total_timesteps  | 265286   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.27     |
# |    n_updates        | 63821    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 524      |
# |    ep_rew_mean      | 131      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1680     |
# |    fps              | 918      |
# |    time_elapsed     | 298      |
# |    total_timesteps  | 274455   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.09     |
# |    n_updates        | 66113    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 492      |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1700     |
# |    fps              | 913      |
# |    time_elapsed     | 309      |
# |    total_timesteps  | 282743   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.27     |
# |    n_updates        | 68185    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 455      |
# |    ep_rew_mean      | 183      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1720     |
# |    fps              | 908      |
# |    time_elapsed     | 320      |
# |    total_timesteps  | 290845   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.17     |
# |    n_updates        | 70211    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 433      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1740     |
# |    fps              | 904      |
# |    time_elapsed     | 330      |
# |    total_timesteps  | 299006   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.502    |
# |    n_updates        | 72251    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 411      |
# |    ep_rew_mean      | 210      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1760     |
# |    fps              | 900      |
# |    time_elapsed     | 340      |
# |    total_timesteps  | 306373   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.841    |
# |    n_updates        | 74093    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 394      |
# |    ep_rew_mean      | 212      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1780     |
# |    fps              | 898      |
# |    time_elapsed     | 349      |
# |    total_timesteps  | 313810   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.96     |
# |    n_updates        | 75952    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 390      |
# |    ep_rew_mean      | 213      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1800     |
# |    fps              | 894      |
# |    time_elapsed     | 359      |
# |    total_timesteps  | 321756   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.26     |
# |    n_updates        | 77938    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 382      |
# |    ep_rew_mean      | 221      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1820     |
# |    fps              | 891      |
# |    time_elapsed     | 369      |
# |    total_timesteps  | 329030   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.797    |
# |    n_updates        | 79757    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 371      |
# |    ep_rew_mean      | 229      |
# ...
# |    n_updates        | 262896   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 254      |
# |    ep_rew_mean      | 257      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5000     |
# |    fps              | 808      |
# |    time_elapsed     | 1319     |
# |    total_timesteps  | 1066838  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0902   |
# |    n_updates        | 264209   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 241      |
# |    ep_rew_mean      | 253      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5020     |
# |    fps              | 808      |
# |    time_elapsed     | 1325     |
# |    total_timesteps  | 1071446  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.344    |
# |    n_updates        | 265361   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 257      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5040     |
# |    fps              | 808      |
# |    time_elapsed     | 1331     |
# |    total_timesteps  | 1076053  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.84     |
# |    n_updates        | 266513   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 257      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5060     |
# |    fps              | 808      |
# |    time_elapsed     | 1337     |
# |    total_timesteps  | 1080697  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.23     |
# |    n_updates        | 267674   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 254      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5080     |
# |    fps              | 807      |
# |    time_elapsed     | 1343     |
# |    total_timesteps  | 1085510  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.98     |
# |    n_updates        | 268877   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 249      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5100     |
# |    fps              | 807      |
# |    time_elapsed     | 1350     |
# |    total_timesteps  | 1090813  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.56     |
# |    n_updates        | 270203   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 242      |
# |    ep_rew_mean      | 250      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5120     |
# |    fps              | 807      |
# |    time_elapsed     | 1356     |
# |    total_timesteps  | 1095673  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.223    |
# |    n_updates        | 271418   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 242      |
# |    ep_rew_mean      | 241      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5140     |
# |    fps              | 807      |
# |    time_elapsed     | 1362     |
# |    total_timesteps  | 1100227  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.6      |
# |    n_updates        | 272556   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 247      |
# |    ep_rew_mean      | 240      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5160     |
# |    fps              | 807      |
# |    time_elapsed     | 1369     |
# |    total_timesteps  | 1105394  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.54     |
# |    n_updates        | 273848   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 253      |
# |    ep_rew_mean      | 242      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5180     |
# |    fps              | 807      |
# |    time_elapsed     | 1376     |
# |    total_timesteps  | 1110767  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.607    |
# |    n_updates        | 275191   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 251      |
# |    ep_rew_mean      | 241      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5200     |
# |    fps              | 806      |
# |    time_elapsed     | 1382     |
# |    total_timesteps  | 1115893  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.156    |
# |    n_updates        | 276473   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 243      |
# |    ep_rew_mean      | 228      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5220     |
# |    fps              | 806      |
# |    time_elapsed     | 1388     |
# |    total_timesteps  | 1120022  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.146    |
# |    n_updates        | 277505   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 245      |
# |    ep_rew_mean      | 229      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5240     |
# |    fps              | 806      |
# |    time_elapsed     | 1394     |
# |    total_timesteps  | 1124765  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0964   |
# |    n_updates        | 278691   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 227      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5260     |
# |    fps              | 806      |
# |    time_elapsed     | 1400     |
# |    total_timesteps  | 1129311  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.175    |
# |    n_updates        | 279827   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 230      |
# |    ep_rew_mean      | 218      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5280     |
# |    fps              | 806      |
# |    time_elapsed     | 1405     |
# |    total_timesteps  | 1133805  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.186    |
# |    n_updates        | 280951   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 227      |
# |    ep_rew_mean      | 213      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5300     |
# |    fps              | 806      |
# |    time_elapsed     | 1412     |
# |    total_timesteps  | 1138623  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.743    |
# |    n_updates        | 282155   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 229      |
# |    ep_rew_mean      | 224      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5320     |
# |    fps              | 806      |
# |    time_elapsed     | 1417     |
# |    total_timesteps  | 1142927  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.22     |
# |    n_updates        | 283231   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 218      |
# |    ep_rew_mean      | 219      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5340     |
# |    fps              | 806      |
# |    time_elapsed     | 1422     |
# |    total_timesteps  | 1146522  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.712    |
# |    n_updates        | 284130   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 214      |
# |    ep_rew_mean      | 218      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5360     |
# |    fps              | 805      |
# |    time_elapsed     | 1427     |
# |    total_timesteps  | 1150696  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.45     |
# |    n_updates        | 285173   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 209      |
# |    ep_rew_mean      | 216      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5380     |
# |    fps              | 805      |
# |    time_elapsed     | 1432     |
# |    total_timesteps  | 1154674  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.88     |
# |    n_updates        | 286168   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 219      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5400     |
# |    fps              | 805      |
# |    time_elapsed     | 1437     |
# |    total_timesteps  | 1158544  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.694    |
# |    n_updates        | 287135   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 201      |
# |    ep_rew_mean      | 224      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5420     |
# |    fps              | 805      |
# |    time_elapsed     | 1443     |
# |    total_timesteps  | 1163024  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.109    |
# |    n_updates        | 288255   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 206      |
# |    ep_rew_mean      | 229      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5440     |
# |    fps              | 805      |
# |    time_elapsed     | 1449     |
# |    total_timesteps  | 1167161  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.84     |
# |    n_updates        | 289290   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 208      |
# |    ep_rew_mean      | 231      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5460     |
# |    fps              | 805      |
# |    time_elapsed     | 1454     |
# |    total_timesteps  | 1171539  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.18     |
# |    n_updates        | 290384   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 213      |
# |    ep_rew_mean      | 238      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5480     |
# |    fps              | 805      |
# |    time_elapsed     | 1460     |
# |    total_timesteps  | 1175946  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.59     |
# |    n_updates        | 291486   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 224      |
# |    ep_rew_mean      | 237      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5500     |
# |    fps              | 805      |
# |    time_elapsed     | 1466     |
# |    total_timesteps  | 1180956  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.82     |
# |    n_updates        | 292738   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 233      |
# |    ep_rew_mean      | 238      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5520     |
# |    fps              | 804      |
# |    time_elapsed     | 1473     |
# |    total_timesteps  | 1186295  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.104    |
# |    n_updates        | 294073   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 238      |
# |    ep_rew_mean      | 240      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5540     |
# |    fps              | 804      |
# |    time_elapsed     | 1479     |
# |    total_timesteps  | 1190932  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.516    |
# |    n_updates        | 295232   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 237      |
# |    ep_rew_mean      | 242      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5560     |
# |    fps              | 804      |
# |    time_elapsed     | 1485     |
# |    total_timesteps  | 1195266  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.464    |
# |    n_updates        | 296316   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 237      |
# |    ep_rew_mean      | 245      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5580     |
# |    fps              | 804      |
# |    time_elapsed     | 1490     |
# |    total_timesteps  | 1199649  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.227    |
# |    n_updates        | 297412   |
# ----------------------------------
# Training complete. Model saved at: lander_stage1_sanity
# Eval mean reward over 100 episodes: 265.49 +/- 56.90
# ✅ SOLVED (>=200)
# (265.48665816, 56.895356254453816)

# %%
print(trainer1.env.action_space)
print(trainer1.env.observation_space)
# Out:
# Discrete(4)
# Box([ -2.5        -2.5       -10.        -10.         -6.2831855 -10.
#   -0.         -0.       ], [ 2.5        2.5       10.        10.         6.2831855 10.
#   1.         1.       ], (8,), float32)

# %% [markdown]
# # Etapa 1 Fine Tune

# %%
def create_dqn_model_finetune(env):
    return DQN(
        "MlpPolicy",
        env,
        learning_rate=2.5e-4,       # lower than 1e-3
        buffer_size=300_000,
        learning_starts=0,          # fine-tuning: start learning immediately
        batch_size=64,
        gamma=0.99,
        train_freq=4,
        gradient_steps=1,
        target_update_interval=1_000,
        exploration_fraction=0.05,  # very little exploration
        exploration_initial_eps=0.05,
        exploration_final_eps=0.01,
        policy_kwargs=dict(net_arch=[256, 256]),
        verbose=1,
    )

# %%
trainer1_ft = LunarLanderTrainer(
    model_fn=create_dqn_model_finetune,
    gravity=-10.0,
    enable_wind=False,
    wind_power=0.0,
    turbulence_power=0.0,
    total_timesteps=400_000,           # +400k polish
    log_dir="./logs_stage1_finetune",
    n_envs=1
)
trainer1_ft.model = DQN.load("lander_stage1_sanity", env=trainer1_ft.env)

trainer1_ft.train("lander_stage1_finetune")
trainer1_ft.evaluate(100)
# Out:
# Using cuda device
# Logging to ./logs_stage1_finetune
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.4     |
# |    ep_rew_mean      | -156     |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 7116     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1748     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | -163     |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 7295     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3520     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.6     |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.935    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 7284     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5434     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.6     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.917    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 7166     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7006     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.1     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.895    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 7184     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8813     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.5     |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.875    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 5670     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10500    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.86     |
# |    n_updates        | 297624   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.3     |
# |    ep_rew_mean      | -158     |
# |    exploration_rate | 0.852    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 3396     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 12455    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.04     |
# |    n_updates        | 298113   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.2     |
# |    ep_rew_mean      | -149     |
# |    exploration_rate | 0.831    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 2682     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 14255    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3        |
# |    n_updates        | 298563   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -133     |
# |    exploration_rate | 0.809    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 2288     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 16126    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.6      |
# |    n_updates        | 299031   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.2     |
# |    ep_rew_mean      | -116     |
# |    exploration_rate | 0.786    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 2042     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 18032    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 6.62     |
# |    n_updates        | 299507   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.6     |
# |    ep_rew_mean      | -110     |
# |    exploration_rate | 0.763    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1836     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 19960    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.18     |
# |    n_updates        | 299989   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93       |
# |    ep_rew_mean      | -105     |
# |    exploration_rate | 0.742    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1696     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 21756    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.3      |
# |    n_updates        | 300438   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.5     |
# |    ep_rew_mean      | -91.7    |
# |    exploration_rate | 0.718    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1610     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 23709    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.846    |
# |    n_updates        | 300927   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -86.8    |
# |    exploration_rate | 0.687    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 1518     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 26365    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.55     |
# |    n_updates        | 301591   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -75.3    |
# |    exploration_rate | 0.665    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 1467     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 28215    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.427    |
# |    n_updates        | 302053   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -70.7    |
# |    exploration_rate | 0.641    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 1422     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 30204    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.26     |
# |    n_updates        | 302550   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | -65.7    |
# |    exploration_rate | 0.617    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 1359     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 32219    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.25     |
# |    n_updates        | 303054   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 110      |
# |    ep_rew_mean      | -63.8    |
# |    exploration_rate | 0.588    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 1322     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 34711    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.92     |
# |    n_updates        | 303677   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | -60.5    |
# |    exploration_rate | 0.561    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 1293     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 36967    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.02     |
# |    n_updates        | 304241   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 108      |
# |    ep_rew_mean      | -55.8    |
# |    exploration_rate | 0.537    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 1267     |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 39024    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.43     |
# |    n_updates        | 304755   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 114      |
# |    ep_rew_mean      | -48.8    |
# |    exploration_rate | 0.506    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 1240     |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 41602    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.814    |
# |    n_updates        | 305400   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 125      |
# |    ep_rew_mean      | -46.9    |
# |    exploration_rate | 0.469    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 1197     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 44721    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.84     |
# |    n_updates        | 306180   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 125      |
# |    ep_rew_mean      | -44      |
# |    exploration_rate | 0.439    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 1177     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 47253    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.69     |
# |    n_updates        | 306813   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 125      |
# |    ep_rew_mean      | -35.9    |
# |    exploration_rate | 0.412    |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 1162     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 49501    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.16     |
# |    n_updates        | 307375   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 142      |
# |    ep_rew_mean      | -34.5    |
# |    exploration_rate | 0.368    |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 1128     |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 53254    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.64     |
# |    n_updates        | 308313   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | -27      |
# |    exploration_rate | 0.296    |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 1096     |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 59316    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.84     |
# |    n_updates        | 309828   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 228      |
# |    ep_rew_mean      | -4.21    |
# |    exploration_rate | 0.199    |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 1049     |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 67486    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 8.31     |
# |    n_updates        | 311871   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 313      |
# |    ep_rew_mean      | 15.1     |
# |    exploration_rate | 0.0668   |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 1002     |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 78584    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.11     |
# |    n_updates        | 314645   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 396      |
# |    ep_rew_mean      | 47.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 967      |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 89073    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.11     |
# |    n_updates        | 317268   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 464      |
# |    ep_rew_mean      | 77       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 938      |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 99675    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.34     |
# |    n_updates        | 319918   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 620      |
# |    fps              | 920      |
# |    time_elapsed     | 118      |
# |    total_timesteps  | 109324   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.592    |
# |    n_updates        | 322330   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 496      |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 640      |
# |    fps              | 908      |
# |    time_elapsed     | 128      |
# |    total_timesteps  | 117060   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.736    |
# |    n_updates        | 324264   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 458      |
# |    ep_rew_mean      | 189      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 660      |
# |    fps              | 899      |
# |    time_elapsed     | 138      |
# |    total_timesteps  | 124379   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.61     |
# |    n_updates        | 326094   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 429      |
# |    ep_rew_mean      | 213      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 680      |
# |    fps              | 889      |
# |    time_elapsed     | 148      |
# |    total_timesteps  | 131967   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.6      |
# |    n_updates        | 327991   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 408      |
# |    ep_rew_mean      | 233      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 700      |
# |    fps              | 880      |
# |    time_elapsed     | 159      |
# |    total_timesteps  | 140454   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.16     |
# |    n_updates        | 330113   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 395      |
# |    ep_rew_mean      | 239      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 872      |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 148786   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.741    |
# |    n_updates        | 332196   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 387      |
# |    ep_rew_mean      | 236      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 866      |
# |    time_elapsed     | 179      |
# |    total_timesteps  | 155783   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.742    |
# |    n_updates        | 333945   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 406      |
# |    ep_rew_mean      | 226      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 760      |
# |    fps              | 859      |
# |    time_elapsed     | 191      |
# |    total_timesteps  | 164929   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1        |
# |    n_updates        | 336232   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 435      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 780      |
# |    fps              | 854      |
# |    time_elapsed     | 205      |
# |    total_timesteps  | 175433   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.24     |
# |    n_updates        | 338858   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 450      |
# |    ep_rew_mean      | 181      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 848      |
# |    time_elapsed     | 218      |
# |    total_timesteps  | 185408   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.67     |
# |    n_updates        | 341351   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 467      |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 820      |
# |    fps              | 844      |
# |    time_elapsed     | 231      |
# |    total_timesteps  | 195518   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.08     |
# |    n_updates        | 343879   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 513      |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 840      |
# |    fps              | 838      |
# |    time_elapsed     | 247      |
# |    total_timesteps  | 207106   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.531    |
# |    n_updates        | 346776   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 529      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 860      |
# |    fps              | 834      |
# |    time_elapsed     | 260      |
# |    total_timesteps  | 217862   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.38     |
# |    n_updates        | 349465   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 516      |
# |    ep_rew_mean      | 132      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 880      |
# |    fps              | 831      |
# |    time_elapsed     | 273      |
# |    total_timesteps  | 227069   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 6.15     |
# |    n_updates        | 351767   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 499      |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 900      |
# |    fps              | 828      |
# |    time_elapsed     | 283      |
# |    total_timesteps  | 235306   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.389    |
# |    n_updates        | 353826   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 480      |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 920      |
# |    fps              | 826      |
# |    time_elapsed     | 294      |
# |    total_timesteps  | 243505   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.58     |
# |    n_updates        | 355876   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 437      |
# |    ep_rew_mean      | 168      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 940      |
# |    fps              | 825      |
# |    time_elapsed     | 303      |
# |    total_timesteps  | 250789   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.193    |
# |    n_updates        | 357697   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 402      |
# |    ep_rew_mean      | 187      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 960      |
# |    fps              | 822      |
# |    time_elapsed     | 313      |
# |    total_timesteps  | 258033   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.792    |
# |    n_updates        | 359508   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 367      |
# |    ep_rew_mean      | 182      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 980      |
# |    fps              | 820      |
# |    time_elapsed     | 321      |
# |    total_timesteps  | 263807   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.216    |
# |    n_updates        | 360951   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 355      |
# |    ep_rew_mean      | 193      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1000     |
# |    fps              | 819      |
# |    time_elapsed     | 330      |
# |    total_timesteps  | 270812   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.157    |
# |    n_updates        | 362702   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 335      |
# |    ep_rew_mean      | 191      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1020     |
# |    fps              | 818      |
# |    time_elapsed     | 338      |
# |    total_timesteps  | 277031   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.23     |
# |    n_updates        | 364257   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 321      |
# |    ep_rew_mean      | 182      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1040     |
# |    fps              | 816      |
# |    time_elapsed     | 346      |
# |    total_timesteps  | 282884   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.215    |
# |    n_updates        | 365720   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 298      |
# |    ep_rew_mean      | 167      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1060     |
# |    fps              | 815      |
# |    time_elapsed     | 353      |
# |    total_timesteps  | 287835   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.221    |
# |    n_updates        | 366958   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 309      |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1080     |
# |    fps              | 814      |
# |    time_elapsed     | 361      |
# |    total_timesteps  | 294708   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.244    |
# |    n_updates        | 368676   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 308      |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1100     |
# |    fps              | 812      |
# |    time_elapsed     | 371      |
# |    total_timesteps  | 301626   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.117    |
# |    n_updates        | 370406   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 316      |
# |    ep_rew_mean      | 167      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1120     |
# |    fps              | 811      |
# |    time_elapsed     | 380      |
# |    total_timesteps  | 308638   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.774    |
# |    n_updates        | 372159   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 333      |
# |    ep_rew_mean      | 179      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1140     |
# |    fps              | 810      |
# |    time_elapsed     | 390      |
# |    total_timesteps  | 316140   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.59     |
# |    n_updates        | 374034   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 353      |
# |    ep_rew_mean      | 192      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1160     |
# |    fps              | 808      |
# |    time_elapsed     | 399      |
# |    total_timesteps  | 323155   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.117    |
# |    n_updates        | 375788   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 344      |
# |    ep_rew_mean      | 201      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1180     |
# |    fps              | 807      |
# |    time_elapsed     | 407      |
# |    total_timesteps  | 329110   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.04     |
# |    n_updates        | 377277   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 335      |
# |    ep_rew_mean      | 187      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1200     |
# |    fps              | 806      |
# |    time_elapsed     | 415      |
# |    total_timesteps  | 335100   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.159    |
# |    n_updates        | 378774   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 340      |
# |    ep_rew_mean      | 196      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1220     |
# |    fps              | 805      |
# |    time_elapsed     | 425      |
# |    total_timesteps  | 342650   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.619    |
# |    n_updates        | 380662   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 343      |
# |    ep_rew_mean      | 206      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1240     |
# |    fps              | 804      |
# |    time_elapsed     | 435      |
# |    total_timesteps  | 350424   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.664    |
# |    n_updates        | 382605   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 337      |
# |    ep_rew_mean      | 216      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1260     |
# |    fps              | 803      |
# |    time_elapsed     | 443      |
# |    total_timesteps  | 356847   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.211    |
# |    n_updates        | 384211   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 337      |
# |    ep_rew_mean      | 222      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1280     |
# |    fps              | 802      |
# |    time_elapsed     | 452      |
# |    total_timesteps  | 362806   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.15     |
# |    n_updates        | 385701   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 331      |
# |    ep_rew_mean      | 233      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1300     |
# |    fps              | 801      |
# |    time_elapsed     | 459      |
# |    total_timesteps  | 368231   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.323    |
# |    n_updates        | 387057   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 321      |
# |    ep_rew_mean      | 232      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1320     |
# |    fps              | 801      |
# |    time_elapsed     | 467      |
# |    total_timesteps  | 374754   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.162    |
# |    n_updates        | 388688   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 297      |
# |    ep_rew_mean      | 226      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1340     |
# |    fps              | 800      |
# |    time_elapsed     | 474      |
# |    total_timesteps  | 380094   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.198    |
# |    n_updates        | 390023   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 273      |
# |    ep_rew_mean      | 213      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1360     |
# |    fps              | 799      |
# |    time_elapsed     | 480      |
# |    total_timesteps  | 384178   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.924    |
# |    n_updates        | 391044   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 255      |
# |    ep_rew_mean      | 198      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1380     |
# |    fps              | 799      |
# |    time_elapsed     | 486      |
# |    total_timesteps  | 388333   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.211    |
# |    n_updates        | 392083   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 265      |
# |    ep_rew_mean      | 206      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1400     |
# |    fps              | 797      |
# |    time_elapsed     | 494      |
# |    total_timesteps  | 394763   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0916   |
# |    n_updates        | 393690   |
# ----------------------------------
# Training complete. Model saved at: lander_stage1_finetune
# Eval mean reward over 100 episodes: 255.71 +/- 47.48
# ✅ SOLVED (>=200)
# (255.70815299000006, 47.47777028642905)

# %% [markdown]
# # Entrenamiento 2A sin viento

# %%
# Variación gravedad (sin viento)
# Stage 2a: gravity -11
trainer2a = LunarLanderTrainer(
    model_fn=create_dqn_model_finetune,
    gravity=-11.0,
    enable_wind=False,
    wind_power=0.0,
    turbulence_power=0.0,
    total_timesteps=250_000,
    log_dir="./logs_stage2a_g-11",
    n_envs=1
)
trainer2a.model = DQN.load("lander_stage1_finetune", env=trainer2a.env)
trainer2a.train("lander_stage2a_g-11")
trainer2a.evaluate(100)
# Out:
# Using cuda device
# Logging to ./logs_stage2a_g-11
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.4     |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 6789     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1728     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.9     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 7030     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3596     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.9     |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 7025     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5276     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.4     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.867    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 7039     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6990     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87       |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.835    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 6966     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8702     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86       |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.804    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 6020     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10323    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 6.6      |
# |    n_updates        | 395080   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.9     |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.77     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 3578     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 12088    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.53     |
# |    n_updates        | 395521   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.4     |
# |    ep_rew_mean      | -150     |
# |    exploration_rate | 0.737    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 2736     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 13818    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.03     |
# |    n_updates        | 395954   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85       |
# |    ep_rew_mean      | -127     |
# |    exploration_rate | 0.706    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 2264     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 15494    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.808    |
# |    n_updates        | 396373   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.5     |
# |    ep_rew_mean      | -106     |
# |    exploration_rate | 0.67     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1942     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 17353    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.21     |
# |    n_updates        | 396838   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.6     |
# |    ep_rew_mean      | -91.1    |
# |    exploration_rate | 0.637    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1786     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 19080    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.23     |
# |    n_updates        | 397269   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.2     |
# |    ep_rew_mean      | -89.3    |
# |    exploration_rate | 0.601    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1663     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 21011    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.26     |
# |    n_updates        | 397752   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | -84.2    |
# |    exploration_rate | 0.564    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1567     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 22961    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.8      |
# |    n_updates        | 398240   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.6     |
# |    ep_rew_mean      | -82.9    |
# |    exploration_rate | 0.528    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 1494     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 24850    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.37     |
# |    n_updates        | 398712   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.4     |
# |    ep_rew_mean      | -78.9    |
# |    exploration_rate | 0.495    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 1424     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 26595    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.41     |
# |    n_updates        | 399148   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.3     |
# |    ep_rew_mean      | -69.3    |
# |    exploration_rate | 0.46     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 1357     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 28407    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.43     |
# |    n_updates        | 399601   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.2     |
# |    ep_rew_mean      | -63.1    |
# |    exploration_rate | 0.426    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 1317     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 30232    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.21     |
# |    n_updates        | 400057   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | -57.7    |
# |    exploration_rate | 0.39     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 1281     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 32101    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.92     |
# |    n_updates        | 400525   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -46.9    |
# |    exploration_rate | 0.354    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 1250     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 34002    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.874    |
# |    n_updates        | 401000   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.5     |
# |    ep_rew_mean      | -38.4    |
# |    exploration_rate | 0.319    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 1223     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 35842    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.561    |
# |    n_updates        | 401460   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.5     |
# |    ep_rew_mean      | -28      |
# |    exploration_rate | 0.271    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 1174     |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 38358    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.07     |
# |    n_updates        | 402089   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -12.6    |
# |    exploration_rate | 0.211    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 1138     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 41546    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 6.32     |
# |    n_updates        | 402886   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 124      |
# |    ep_rew_mean      | 2.36     |
# |    exploration_rate | 0.154    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 1108     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 44526    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.02     |
# |    n_updates        | 403631   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 129      |
# |    ep_rew_mean      | 15.7     |
# |    exploration_rate | 0.11     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 1078     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 46859    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.11     |
# |    n_updates        | 404214   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 146      |
# |    ep_rew_mean      | 41.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 1050     |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 50403    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 5.81     |
# |    n_updates        | 405100   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | 58.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 1026     |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 53834    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.497    |
# |    n_updates        | 405958   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 160      |
# |    ep_rew_mean      | 79.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 997      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 57584    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.3      |
# |    n_updates        | 406895   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | 98       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 977      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 62040    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.26     |
# |    n_updates        | 408009   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | 117      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 955      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 66184    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.717    |
# |    n_updates        | 409045   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 208      |
# |    ep_rew_mean      | 129      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 939      |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 71250    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.13     |
# |    n_updates        | 410312   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 232      |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 620      |
# |    fps              | 919      |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 76989    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 5.47     |
# |    n_updates        | 411747   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 237      |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 640      |
# |    fps              | 908      |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 81329    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.05     |
# |    n_updates        | 412832   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 258      |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 660      |
# |    fps              | 895      |
# |    time_elapsed     | 98       |
# |    total_timesteps  | 87837    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.6      |
# |    n_updates        | 414459   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 275      |
# |    ep_rew_mean      | 174      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 680      |
# |    fps              | 883      |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 93639    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.41     |
# |    n_updates        | 415909   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 292      |
# |    ep_rew_mean      | 173      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 700      |
# |    fps              | 872      |
# |    time_elapsed     | 115      |
# |    total_timesteps  | 100447   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.792    |
# |    n_updates        | 417611   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 317      |
# |    ep_rew_mean      | 175      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 861      |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 108699   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.21     |
# |    n_updates        | 419674   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 375      |
# |    ep_rew_mean      | 173      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 851      |
# |    time_elapsed     | 139      |
# |    total_timesteps  | 118869   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.12     |
# |    n_updates        | 422217   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 408      |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 760      |
# |    fps              | 844      |
# |    time_elapsed     | 152      |
# |    total_timesteps  | 128613   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.38     |
# |    n_updates        | 424653   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 445      |
# |    ep_rew_mean      | 100      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 780      |
# |    fps              | 837      |
# |    time_elapsed     | 164      |
# |    total_timesteps  | 138184   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.9      |
# |    n_updates        | 427045   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 459      |
# |    ep_rew_mean      | 82.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 832      |
# |    time_elapsed     | 175      |
# |    total_timesteps  | 146337   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.474    |
# |    n_updates        | 429084   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 464      |
# |    ep_rew_mean      | 72.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 820      |
# |    fps              | 827      |
# |    time_elapsed     | 187      |
# |    total_timesteps  | 155147   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.515    |
# |    n_updates        | 431286   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 461      |
# |    ep_rew_mean      | 81.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 840      |
# |    fps              | 822      |
# |    time_elapsed     | 200      |
# |    total_timesteps  | 164976   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.916    |
# |    n_updates        | 433743   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 473      |
# |    ep_rew_mean      | 98.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 860      |
# |    fps              | 818      |
# |    time_elapsed     | 214      |
# |    total_timesteps  | 175886   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.349    |
# |    n_updates        | 436471   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 449      |
# |    ep_rew_mean      | 132      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 880      |
# |    fps              | 814      |
# |    time_elapsed     | 224      |
# |    total_timesteps  | 183118   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.573    |
# |    n_updates        | 438279   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 435      |
# |    ep_rew_mean      | 168      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 900      |
# |    fps              | 812      |
# |    time_elapsed     | 233      |
# |    total_timesteps  | 189884   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.24     |
# |    n_updates        | 439970   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 409      |
# |    ep_rew_mean      | 192      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 920      |
# |    fps              | 811      |
# |    time_elapsed     | 241      |
# |    total_timesteps  | 196083   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.35     |
# |    n_updates        | 441520   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 378      |
# |    ep_rew_mean      | 208      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 940      |
# |    fps              | 808      |
# |    time_elapsed     | 250      |
# |    total_timesteps  | 202750   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.416    |
# |    n_updates        | 443187   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 331      |
# |    ep_rew_mean      | 237      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 960      |
# |    fps              | 806      |
# |    time_elapsed     | 259      |
# |    total_timesteps  | 209029   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.883    |
# |    n_updates        | 444757   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 313      |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 980      |
# |    fps              | 804      |
# |    time_elapsed     | 266      |
# |    total_timesteps  | 214416   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.551    |
# |    n_updates        | 446103   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 308      |
# |    ep_rew_mean      | 235      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1000     |
# |    fps              | 803      |
# |    time_elapsed     | 274      |
# |    total_timesteps  | 220709   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.71     |
# |    n_updates        | 447677   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 304      |
# |    ep_rew_mean      | 235      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1020     |
# |    fps              | 801      |
# |    time_elapsed     | 282      |
# |    total_timesteps  | 226468   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.59     |
# |    n_updates        | 449116   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 294      |
# |    ep_rew_mean      | 240      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1040     |
# |    fps              | 799      |
# |    time_elapsed     | 290      |
# |    total_timesteps  | 232157   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.483    |
# |    n_updates        | 450539   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 283      |
# |    ep_rew_mean      | 231      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1060     |
# |    fps              | 798      |
# |    time_elapsed     | 297      |
# |    total_timesteps  | 237329   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.01     |
# |    n_updates        | 451832   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 274      |
# |    ep_rew_mean      | 226      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1080     |
# |    fps              | 797      |
# |    time_elapsed     | 303      |
# |    total_timesteps  | 241832   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.537    |
# |    n_updates        | 452957   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 251      |
# |    ep_rew_mean      | 203      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1100     |
# |    fps              | 796      |
# |    time_elapsed     | 308      |
# |    total_timesteps  | 245836   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.365    |
# |    n_updates        | 453958   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 231      |
# |    ep_rew_mean      | 180      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1120     |
# |    fps              | 795      |
# |    time_elapsed     | 313      |
# |    total_timesteps  | 249521   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.374    |
# |    n_updates        | 454880   |
# ----------------------------------
# Training complete. Model saved at: lander_stage2a_g-11
# Eval mean reward over 100 episodes: 172.11 +/- 111.15
# ❌ Not solved yet
# (172.11065156, 111.14902302423864)

# %% [markdown]
# # Etapa 2 graved=-9 No viento

# %%
# Stage 2b: gravity -9
trainer2b = LunarLanderTrainer(
    model_fn=create_dqn_model_finetune,
    gravity=-9.0,
    enable_wind=False,
    wind_power=0.0,
    turbulence_power=0.0,
    total_timesteps=250_000,
    log_dir="./logs_stage2b_g-9",
    n_envs=1
)
trainer2b.model = DQN.load("lander_stage2a_g-11", env=trainer2b.env)
trainer2b.train("lander_stage2b_g-9")
trainer2b.evaluate(100)
# Out:
# Using cuda device
# Logging to ./logs_stage2b_g-9
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.1     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 7222     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1882     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96       |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 7242     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3841     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.5     |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.889    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 7163     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5852     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.8     |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.853    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 7168     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7748     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.5     |
# |    ep_rew_mean      | -209     |
# |    exploration_rate | 0.817    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 7177     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9647     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.4     |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.777    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 3888     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 11718    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.85     |
# |    n_updates        | 455429   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.736    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 2717     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 13889    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.02     |
# |    n_updates        | 455972   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -143     |
# |    exploration_rate | 0.698    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 2251     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 15872    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.29     |
# |    n_updates        | 456467   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -111     |
# |    exploration_rate | 0.659    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1936     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 17945    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.03     |
# |    n_updates        | 456986   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | -70.2    |
# |    exploration_rate | 0.619    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1720     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 20068    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.19     |
# |    n_updates        | 457516   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | -53.9    |
# |    exploration_rate | 0.576    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1592     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 22322    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.81     |
# |    n_updates        | 458080   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 107      |
# |    ep_rew_mean      | -48.8    |
# |    exploration_rate | 0.532    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1501     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 24609    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.74     |
# |    n_updates        | 458652   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 110      |
# |    ep_rew_mean      | -36      |
# |    exploration_rate | 0.489    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1430     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 26890    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 5.01     |
# |    n_updates        | 459222   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 112      |
# |    ep_rew_mean      | -22.2    |
# |    exploration_rate | 0.446    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 1354     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 29149    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.49     |
# |    n_updates        | 459787   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 114      |
# |    ep_rew_mean      | -17.3    |
# |    exploration_rate | 0.403    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 1300     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 31439    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.62     |
# |    n_updates        | 460359   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 119      |
# |    ep_rew_mean      | -9.31    |
# |    exploration_rate | 0.35     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 1254     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 34210    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.485    |
# |    n_updates        | 461052   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 130      |
# |    ep_rew_mean      | 2.37     |
# |    exploration_rate | 0.286    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 1206     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 37564    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.9      |
# |    n_updates        | 461890   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 172      |
# |    ep_rew_mean      | 24.6     |
# |    exploration_rate | 0.162    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 1115     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 44128    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.25     |
# |    n_updates        | 463531   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 209      |
# |    ep_rew_mean      | 49.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 1053     |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 50033    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.22     |
# |    n_updates        | 465008   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 260      |
# |    ep_rew_mean      | 97.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 998      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 57447    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.82     |
# |    n_updates        | 466861   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 294      |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 971      |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 63659    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.26     |
# |    n_updates        | 468414   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 341      |
# |    ep_rew_mean      | 183      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 941      |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 71646    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.919    |
# |    n_updates        | 470411   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 375      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 914      |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 81583    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.8      |
# |    n_updates        | 472895   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 411      |
# |    ep_rew_mean      | 210      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 895      |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 91156    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.68     |
# |    n_updates        | 475288   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 420      |
# |    ep_rew_mean      | 214      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 879      |
# |    time_elapsed     | 113      |
# |    total_timesteps  | 99473    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.79     |
# |    n_updates        | 477368   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 439      |
# |    ep_rew_mean      | 210      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 868      |
# |    time_elapsed     | 123      |
# |    total_timesteps  | 107598   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.572    |
# |    n_updates        | 479399   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 421      |
# |    ep_rew_mean      | 218      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 860      |
# |    time_elapsed     | 132      |
# |    total_timesteps  | 113719   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.338    |
# |    n_updates        | 480929   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 386      |
# |    ep_rew_mean      | 233      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 852      |
# |    time_elapsed     | 141      |
# |    total_timesteps  | 120220   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.26     |
# |    n_updates        | 482554   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 355      |
# |    ep_rew_mean      | 248      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 848      |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 126694   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.09     |
# |    n_updates        | 484173   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 338      |
# |    ep_rew_mean      | 246      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 842      |
# |    time_elapsed     | 158      |
# |    total_timesteps  | 133244   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.537    |
# |    n_updates        | 485810   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 307      |
# |    ep_rew_mean      | 242      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 620      |
# |    fps              | 838      |
# |    time_elapsed     | 164      |
# |    total_timesteps  | 138297   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.487    |
# |    n_updates        | 487074   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 308      |
# |    ep_rew_mean      | 238      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 640      |
# |    fps              | 835      |
# |    time_elapsed     | 172      |
# |    total_timesteps  | 144502   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.2      |
# |    n_updates        | 488625   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 316      |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 660      |
# |    fps              | 831      |
# |    time_elapsed     | 182      |
# |    total_timesteps  | 151841   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.663    |
# |    n_updates        | 490460   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 321      |
# |    ep_rew_mean      | 221      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 680      |
# |    fps              | 826      |
# |    time_elapsed     | 192      |
# |    total_timesteps  | 158835   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.442    |
# |    n_updates        | 492208   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 351      |
# |    ep_rew_mean      | 212      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 700      |
# |    fps              | 822      |
# |    time_elapsed     | 204      |
# |    total_timesteps  | 168348   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.01     |
# |    n_updates        | 494586   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 378      |
# |    ep_rew_mean      | 215      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 819      |
# |    time_elapsed     | 215      |
# |    total_timesteps  | 176131   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.779    |
# |    n_updates        | 496532   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 392      |
# |    ep_rew_mean      | 218      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 815      |
# |    time_elapsed     | 225      |
# |    total_timesteps  | 183719   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.405    |
# |    n_updates        | 498429   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 373      |
# |    ep_rew_mean      | 220      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 760      |
# |    fps              | 813      |
# |    time_elapsed     | 232      |
# |    total_timesteps  | 189168   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.91     |
# |    n_updates        | 499791   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 368      |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 780      |
# |    fps              | 811      |
# |    time_elapsed     | 241      |
# |    total_timesteps  | 195675   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.757    |
# |    n_updates        | 501418   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 340      |
# |    ep_rew_mean      | 247      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 808      |
# |    time_elapsed     | 250      |
# |    total_timesteps  | 202388   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.619    |
# |    n_updates        | 503096   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 331      |
# |    ep_rew_mean      | 251      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 820      |
# |    fps              | 806      |
# |    time_elapsed     | 259      |
# |    total_timesteps  | 209191   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.222    |
# |    n_updates        | 504797   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 335      |
# |    ep_rew_mean      | 253      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 840      |
# |    fps              | 803      |
# |    time_elapsed     | 270      |
# |    total_timesteps  | 217199   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.506    |
# |    n_updates        | 506799   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 350      |
# |    ep_rew_mean      | 255      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 860      |
# |    fps              | 802      |
# |    time_elapsed     | 279      |
# |    total_timesteps  | 224192   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.75     |
# |    n_updates        | 508547   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 353      |
# |    ep_rew_mean      | 253      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 880      |
# |    fps              | 800      |
# |    time_elapsed     | 288      |
# |    total_timesteps  | 230971   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.371    |
# |    n_updates        | 510242   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 356      |
# |    ep_rew_mean      | 254      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 900      |
# |    fps              | 798      |
# |    time_elapsed     | 297      |
# |    total_timesteps  | 237943   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.62     |
# |    n_updates        | 511985   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 354      |
# |    ep_rew_mean      | 252      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 920      |
# |    fps              | 796      |
# |    time_elapsed     | 306      |
# |    total_timesteps  | 244583   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.04     |
# |    n_updates        | 513645   |
# ----------------------------------
# Training complete. Model saved at: lander_stage2b_g-9
# Eval mean reward over 100 episodes: 243.00 +/- 68.96
# ✅ SOLVED (>=200)
# (242.99547177000005, 68.96400750894459)

# %%
# Optional: gravity -11 (harder)
trainer2c = LunarLanderTrainer(
    model_fn=create_dqn_model_finetune,
    gravity=-11.0,
    enable_wind=False,
    wind_power=0.0,
    turbulence_power=0.0,
    total_timesteps=250_000,
    log_dir="./logs_stage2c_g-12",
    n_envs=1
)
trainer2c.model = DQN.load("lander_stage2b_g-9", env=trainer2c.env)e
trainer2c.train("lander_stage2c_g-12")
trainer2c.evaluate(100)
# Out:
#   File "/tmp/ipython-input-1099001153.py", line 12
#     trainer2c.model = DQN.load("lander_stage2b_g-9", env=trainer2c.env)e
#                                                                        ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Etapa 3 viento fine tune

# %%
stage3_kwargs = dict(
    learning_rate=2.5e-4,
    buffer_size=300_000,
    learning_starts=10_000,
    batch_size=64,
    gamma=0.99,
    train_freq=4,
    gradient_steps=1,
    target_update_interval=1000,
    exploration_fraction=0.15,
    exploration_initial_eps=0.20,
    exploration_final_eps=0.05,
    policy_kwargs=dict(net_arch=[256, 256]),
    verbose=1
)

# %%
trainer3 = LunarLanderTrainer(
    model_fn=lambda env: DQN("MlpPolicy", env, verbose=1),  # placeholder
    gravity=-10.0,
    enable_wind=True,
    wind_power=8.0,
    turbulence_power=0.5,
    total_timesteps=500_000,
    log_dir="./logs_stage3_wind_soft_fix",
    n_envs=1
)

# ✅ AQUÍ defines de dónde vienes (tu mejor modelo SIN viento)
# Recomendado: el que ya resolvió Stage 1 (>=200)
load_path_stage3 = "lander_stage1_finetune"   # <-- AJUSTA si usas otro

trainer3.model = load_weights_into_new_model(
    DQN, "MlpPolicy", trainer3.env,
    load_path=load_path_stage3,
    **stage3_kwargs
)

trainer3.train("lander_stage3_wind_soft_fix")
trainer3.evaluate(100)
trainer3.generate_video(model_path="lander_stage3_wind_soft_fix", out_dir="./output_video_stage3")

# %% [markdown]
# ## Etapa 4

# %%
stage4_kwargs = dict(
    learning_rate=1e-4,
    buffer_size=500_000,
    learning_starts=50_000,
    batch_size=128,
    gamma=0.99,
    train_freq=4,
    gradient_steps=1,
    target_update_interval=500,
    exploration_fraction=0.30,
    exploration_initial_eps=0.30,
    exploration_final_eps=0.05,
    policy_kwargs=dict(net_arch=[256, 256]),
    verbose=1
)

# %%
trainer4 = LunarLanderTrainer(
    model_fn=lambda env: DQN("MlpPolicy", env, verbose=1),  # placeholder
    gravity=-10.0,
    enable_wind=True,
    wind_power=18.0,
    turbulence_power=1.5,
    total_timesteps=900_000,
    log_dir="./logs_stage4_wind_strong_v2",
    n_envs=1
)

# ✅ Stage 4 SIEMPRE debe partir del modelo arreglado de Stage 3
trainer4.model = load_weights_into_new_model(
    DQN, "MlpPolicy", trainer4.env,
    load_path="lander_stage3_wind_soft_fix",
    **stage4_kwargs
)

trainer4.train("lander_stage4_wind_strong_v2")
trainer4.evaluate(100)
trainer4.generate_video(model_path="lander_stage4_wind_strong_v2", out_dir="./output_video_stage4")

# %%
# trainer3_1 = LunarLanderTrainer(
#     model_fn=create_dqn_model_wind_finetune,
#     gravity=-10.0,
#     enable_wind=True,
#     wind_power=8.0,
#     turbulence_power=0.5,
#     total_timesteps=400_000,           # +400k polish
#     log_dir="./logs_stage3_1_wind_polish",
#     n_envs=1
# )

# trainer3_1.model = DQN.load("lander_stage3_wind_soft", env=trainer3_1.env)

# trainer3_1.train("lander_stage3_1_wind_polish")
# trainer3_1.evaluate(100)

# %%
# from stable_baselines3 import DQN

# def create_dqn_model_stage4(env):
#     return DQN(
#         "MlpPolicy",
#         env,
#         learning_rate=2.5e-4,          # volver a un LR que ya te funcionó en viento :contentReference[oaicite:3]{index=3}
#         buffer_size=500_000,
#         learning_starts=50_000,        # <- clave: llena buffer en el nuevo dominio antes de aprender
#         batch_size=128,                # batch más grande suele estabilizar en viento fuerte
#         gamma=0.99,
#         train_freq=4,
#         gradient_steps=1,
#         target_update_interval=500,    # updates más frecuentes ayudan a adaptarse (antes era 1000)
#         exploration_fraction=0.30,     # <- más tiempo explorando
#         exploration_initial_eps=0.30,  # <- más exploración al arrancar Stage 4
#         exploration_final_eps=0.05,    # <- no la mates a 0.01 tan rápido en dominio nuevo
#         policy_kwargs=dict(net_arch=[256, 256]),
#         verbose=1,
#     )

# %%
# trainer4 = LunarLanderTrainer(
#     model_fn=lambda env: DQN("MlpPolicy", env, verbose=1),  # placeholder
#     gravity=-10.0,
#     enable_wind=True,
#     wind_power=18.0,
#     turbulence_power=1.5,
#     total_timesteps=900_000,          # dale más; 700k a veces queda corto en este salto
#     log_dir="./logs_stage4_strong_v2",
#     n_envs=1                           # importante: en tus stages duros te fue mejor con n_envs=1
# )

# trainer4.model = load_weights_into_new_model(
#     DQN,
#     "MlpPolicy",
#     trainer4.env,
#     load_path="lander_stage3_fix_real",
#     learning_rate=2.5e-4,
#     buffer_size=500_000,
#     learning_starts=50_000,
#     batch_size=128,
#     gamma=0.99,
#     train_freq=4,
#     gradient_steps=1,
#     target_update_interval=500,
#     exploration_fraction=0.30,
#     exploration_initial_eps=0.30,
#     exploration_final_eps=0.05,
#     policy_kwargs=dict(net_arch=[256, 256]),
#     verbose=1
# )

# trainer4.train("lander_stage4_strong_v2")
# trainer4.evaluate(100)
# trainer4.generate_video(model_path="lander_stage4_strong_v2", out_dir="./output_video_stage4_v2")

# %%
scenarios = [
    (-11.9, False, 0.0, 0.0),
    (-9.0,  False, 0.0, 0.0),
    (-10.0, True,  8.0, 0.5),
    (-10.0, True,  18.0, 1.5),
    (-11.0, True,  20.0, 2.0),
]

means = []
for g, w, wp, tp in scenarios:
    tmp = LunarLanderTrainer(
        model_fn=lambda env: DQN("MlpPolicy", env, verbose=0),
        gravity=g,
        enable_wind=w,
        wind_power=wp,
        turbulence_power=tp,
        total_timesteps=1,
        log_dir="./logs_eval_tmp",
        n_envs=1
    )
    tmp.model = DQN.load("lander_stage4_wind_strong_v2", env=tmp.env)
    m, s = tmp.evaluate(50)
    means.append(m)

overall = float(np.mean(means))
print("Overall mean across scenarios:", overall)
print("✅ SOLVED overall (>=200)" if overall >= 200 else "❌ Not solved overall")

# %%
# # =========================
# # STAGE 1: Fácil (sin viento, gravedad fija)
# # =========================
# trainer1 = run_stage(
#     stage_name="stage1_easy",
#     timesteps=1_200_000,
#     gravity=-10.0,
#     enable_wind=False,
#     wind_power=0.0,
#     turbulence_power=0.0,
#     model_fn=create_dqn_model_stage1_strong,
#     load_model_path=None,
#     save_model_path="lander_stage1",
#     n_envs=1
# )

# %%
# trainer1.generate_video(model_path="lander_stage1")
# trainer1.plot_rewards()

# %%
# # =========================
# # STAGE 2: Generaliza en gravedad (sin viento)
# # Re-entrenamos en 2 gravedades distintas para robustez
# # =========================
# trainer2a = run_stage(
#     stage_name="stage2_grav_-11",
#     timesteps=300_000,
#     gravity=-11.0,
#     enable_wind=False,
#     wind_power=0.0,
#     turbulence_power=0.0,
#     load_model_path="lander_stage1",
#     save_model_path="lander_stage2a",
#     n_envs=8
# )

# trainer2b = run_stage(
#     stage_name="stage2_grav_-9",
#     timesteps=300_000,
#     gravity=-9.0,
#     enable_wind=False,
#     wind_power=0.0,
#     turbulence_power=0.0,
#     load_model_path="lander_stage2a",
#     save_model_path="lander_stage2",
#     n_envs=8
# )

# %%
# trainer2b.generate_video(model_path="lander_stage2")
# trainer2b.plot_rewards()

# %%
# # =========================
# # STAGE 3: Viento suave
# # =========================
# trainer3 = run_stage(
#     stage_name="stage3_wind_soft",
#     timesteps=500_000,
#     gravity=-10.0,
#     enable_wind=True,
#     wind_power=8.0,
#     turbulence_power=0.5,
#     load_model_path="lander_stage2",
#     save_model_path="lander_stage3",
#     n_envs=8
# )

# %%
# trainer3.generate_video(model_path="lander_stage3")
# trainer3.plot_rewards()

# %%
# continuous = False
# gravity = -10.0
# enable_wind = False
# wind_power = 0.0
# turbulence_power = 0.0
# env_render = gymnasium.make(
#     "LunarLander-v3",
#     continuous=continuous,
#     gravity=gravity,
#     enable_wind=enable_wind,
#     wind_power=wind_power,
#     turbulence_power=turbulence_power,
#     render_mode='rgb_array' # Added render_mode for RenderFrame compatibility
# )
# env_render = renderlab.RenderFrame(env_render, "./output")

# terminated = False
# truncated = False
# total_reward = 0

# obs, info = env_render.reset()

# while not (terminated or truncated):
#   action = 0
#   obs, reward, terminated, truncated, info = env_render.step(action)
#   total_reward += reward

# print("Recompensa", total_reward)

# env_render.play()

# %%
# # Callback personalizado para registrar las recompensas por episodio durante el entrenamiento
# class RewardLoggerCallback(BaseCallback):
#     def __init__(self):
#         super().__init__()
#         self.episode_rewards = []  # Lista para almacenar las recompensas de cada episodio

#     def _on_step(self) -> bool:
#         # Verifica si hay información de episodios en los 'infos' proporcionados por el entorno
#         if len(self.locals["infos"]) > 0:
#             for info in self.locals["infos"]:
#                 if "episode" in info:
#                     # Agrega la recompensa del episodio a la lista
#                     self.episode_rewards.append(info["episode"]["r"])
#         return True  # Continúa el entrenamiento

# # Custom wrapper to provide pixel observations for CnnPolicy
# class PixelObservationWrapper(gymnasium.ObservationWrapper):
#     def __init__(self, env):
#         super().__init__(env)
#         # The new observation space will be a single grayscale 84x84x1 image
#         self.observation_space = Box(low=0, high=255, shape=(84, 84, 1), dtype=np.uint8) # Changed shape to 3D

#     def observation(self, obs): # obs here is the original state vector from env.step()
#         # Render the environment to get pixel observations
#         rgb_array = self.env.render()
#         processed_frame = self._preprocess_frame(rgb_array)
#         return processed_frame.reshape(84, 84, 1) # Reshape to (84, 84, 1)

#     def _preprocess_frame(self, frame):
#         # Convert to grayscale and resize
#         gray = frame.mean(axis=2).astype(np.uint8) # Assuming RGB (H, W, 3)
#         resized = cv2.resize(gray, (84, 84), interpolation=cv2.INTER_AREA)
#         return resized # Returns (84, 84)

# # Clase encargada de entrenar al agente en el entorno Freeway
# class LunaLanderTrainer:
#     def __init__(
#         self,
#         model_fn,
#         continuous=False, # Corrected: 'continous' to 'continuous'
#         gravity = -10.0,
#         enable_wind = False,
#         wind_power = 0.0,
#         turbulence_power = 0.0,
#         total_timesteps=204_800,
#         log_dir="./logs"
#         ):
#         self.continuous = continuous # Corrected: 'continous' to 'continuous'
#         self.gravity = gravity
#         self.enable_wind = enable_wind
#         self.wind_power = wind_power
#         self.turbulence_power = turbulence_power
#         self.total_timesteps = total_timesteps  # Número total de pasos de entrenamiento
#         self.log_dir = log_dir  # Carpeta donde se almacenan los logs
#         os.makedirs(log_dir, exist_ok=True)  # Crea la carpeta si no existe

#         # Create the base LunarLander environment with rgb_array render_mode
#         base_env = gymnasium.make(
#             "LunarLander-v3",
#             continuous=self.continuous,
#             gravity=self.gravity,
#             enable_wind=self.enable_wind,
#             wind_power=self.wind_power,
#             turbulence_power=self.turbulence_power,
#             render_mode='rgb_array' # Important for pixel observations
#         )

#         # Wrap with PixelObservationWrapper to get 84x84 grayscale observations
#         pixel_env = PixelObservationWrapper(base_env)

#         # Import 'Monitor' from stable_baselines3.common.monitor
#         from stable_baselines3.common.monitor import Monitor
#         monitored_env = Monitor(pixel_env, filename=os.path.join(log_dir, "monitor.csv"))

#         # Create a DummyVecEnv to wrap the single environment
#         # DummyVecEnv expects a list of callable environment constructors
#         vec_env_single = DummyVecEnv([lambda: monitored_env])

#         # Apply VecFrameStack to stack 4 frames for CnnPolicy input
#         self.env = VecFrameStack(vec_env_single, n_stack=4) # Removed channels_first=True

#         self.model = model_fn(self.env)  # Crea el modelo usando la función proporcionada

#         # Configura un logger personalizado que guarda en consola y en CSV
#         new_logger = configure(log_dir, ["stdout", "csv"])
#         self.model.set_logger(new_logger)

#         # Instancia del callback para registrar recompensas
#         self.callback = RewardLoggerCallback()

#     def train(self, save_path="dqn_lunarlander_model"):
#         # Entrena el modelo y guarda el archivo resultante
#         self.model.learn(total_timesteps=self.total_timesteps, log_interval=20, callback=self.callback)
#         self.model.save(save_path)
#         print("Training complete. Model saved.")  # Mensaje al finalizar

#     def plot_rewards(self):
#         # Grafica la evolución de las recompensas por episodio
#         if not self.callback.episode_rewards:
#             print("No reward data to plot.")  # Si no hay datos, notifica
#             return
#         plt.figure(figsize=(10, 5))
#         plt.plot(self.callback.episode_rewards, label="Episode Reward")
#         plt.xlabel("Episodes")
#         plt.ylabel("Reward")
#         plt.title("Training Rewards Over Time")
#         plt.grid()
#         plt.legend()
#         plt.tight_layout()
#         plt.show()

#     def generate_video(self, model_path="dqn_lunarlander_model"):
#         # Carga el modelo entrenado y genera un video del agente actuando
#         model = self.model.__class__.load(model_path)

#         # Crea el entorno con modo de renderizado RGB para capturar imágenes
#         env = gymnasium.make(
#             "LunarLander-v3", # Changed 'ALE/LunarLander-v3' to 'LunarLander-v3' as 'ALE/' prefix is not needed for LunarLander
#             render_mode="rgb_array",
#             continuous=self.continuous,
#             gravity=self.gravity,
#             enable_wind=self.enable_wind,
#             wind_power=self.wind_power,
#             turbulence_power=self.turbulence_power)
#         env = renderlab.RenderFrame(env, "./output")  # Envuelve el entorno para capturar video

#         frame_stack = deque(maxlen=4)  # Pila de frames para mantener la entrada en el mismo formato que durante el entrenamiento

#         # Función para preprocesar las observaciones: convierte a escala de grises y redimensiona
#         def preprocess(frame_rgb):
#             gray = frame_rgb.mean(axis=2).astype(np.uint8)
#             resized = cv2.resize(gray, (84, 84), interpolation=cv2.INTER_AREA)
#             return resized.reshape(84, 84, 1) # Ensure 3D output here too

#         obs, info = env.reset() # This `obs` is the state vector, not pixel data.
#         # Get initial pixel observation for the frame stack
#         rgb_initial = env.render() # Render to get the RGB array
#         preprocessed_initial = preprocess(rgb_initial)
#         for _ in range(4):
#             frame_stack.append(preprocessed_initial)  # Initialize stack with (84, 84, 1) frames

#         terminated = False
#         truncated = False
#         total_reward = 0  # Acumula la recompensa total del episodio

#         # Ejecuta el episodio hasta que termine
#         while not (terminated or truncated):
#             stacked_obs = np.stack(frame_stack, axis=0) # This will create (4, 84, 84, 1)
#             # NatureCNN expects (batch_size, channels, height, width) or (channels, height, width) for predict
#             # Transpose from (N, H, W, C) to (N, C, H, W) for NatureCNN
#             stacked_obs_for_predict = stacked_obs.transpose(0, 3, 1, 2).squeeze(axis=1) # Resulting shape (4, 84, 84)
#             action, _ = model.predict(stacked_obs_for_predict, deterministic=True)  # Predice la acción a tomar

#             obs, reward, terminated, truncated, info = env.step(action)  # Execute the action (obs here is the state vector)
#             total_reward += reward  # Acumula la recompensa

#             # Get new pixel observation after step
#             rgb_after_step = env.render()
#             preprocessed_after_step = preprocess(rgb_after_step)  # Preprocesa la nueva observación
#             frame_stack.append(preprocessed_after_step)  # Actualiza la pila de frames

#         print("Recompensa obtenida en el episodio:", total_reward)  # Muestra la recompensa obtenida
#         env.play()  # Reproduce el video generado

# %%
# def create_model(env):
#     return DQN(
#         "CnnPolicy",
#         env,
#         learning_rate=0.0001,
#         buffer_size=50000,
#         learning_starts=1024,
#         batch_size=32,
#         gamma=0.99,
#         train_freq=4,
#         target_update_interval=10000,
#         exploration_fraction=0.5,
#         exploration_initial_eps=1.0,
#         exploration_final_eps=0.05,
#         verbose=1,
#         policy_kwargs=dict(net_arch=[256, 256]),
#     )

# trainer = LunaLanderTrainer(
#     model_fn=create_model,
#     continuous=False,
#     gravity = -10.0,
#     enable_wind = False,
#     wind_power = 0.0,
#     turbulence_power = 0.0,
#     total_timesteps=100_000
#     )
# trainer.train()

# %%
# trainer.generate_video()
# trainer.plot_rewards()

# %%
# # Mount Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# # Define the path in Google Drive to save the model
# drive_save_dir = '/content/drive/MyDrive/DRL/my_models'
# import os
# os.makedirs(drive_save_dir, exist_ok=True)

# # Define the local path of the trained model (default name from trainer.train())
# local_model_path = 'dqn_lunarlander_model.zip'

# # Define the full path in Google Drive
# drive_model_path = os.path.join(drive_save_dir, local_model_path)

# # Copy the model to Google Drive
# import shutil
# if os.path.exists(local_model_path):
#     shutil.copy(local_model_path, drive_model_path)
#     print(f"Model saved to Google Drive at: {drive_model_path}")
# else:
#     print(f"Error: Local model '{local_model_path}' not found. Please ensure the training completed successfully.")
